# %% [markdown]
# ## Objectives
#
# - Load and use RandomUser API, using RandomUser() Python library
# - Load and use Fruityvice API, using requests Python library
# - Load and use Open-Joke-API, using requests Python library
#
#
# RandomUser is a free API that provides randomly generated users for testing.
# It can return multiple users with details like gender, email, image, username, address, name, and more.
#
# Fruityvice API provides data and interesting information on various fruits.

# %%
from randomuser import RandomUser
import pandas as pd

# %%
#Create a random user object
r = RandomUser()

# %%
#Then, using generate_users() function, we get a list of random 10 users.
some_list = r.generate_users(10)

# %%
some_list

# %%
#Let's say we only need 10 users with full names and their email addresses. We can write a "for-loop" to print these 10 users.
name = r.get_full_name()

for user in some_list:
    print (user.get_full_name()," ",user.get_email())
# Out:
# Urban Henry   urban.henry@example.com
# Côme Lambert   come.lambert@example.com
# Ceres Nascimento   ceres.nascimento@example.com
# Olivia Kari   olivia.kari@example.com
# Jill Laurent   jill.laurent@example.com
# Sabine Wernicke   sabine.wernicke@example.com
# Capucine Mercier   capucine.mercier@example.com
# Eva Vargas   eva.vargas@example.com
# Liane Hennings   liane.hennings@example.com
# Esperanza Rojas   esperanza.rojas@example.com

# %%
#Generate photos of 10 users
for user in some_list:
    print(user.get_picture())
# Out:
# https://randomuser.me/api/portraits/men/63.jpg
# https://randomuser.me/api/portraits/men/46.jpg
# https://randomuser.me/api/portraits/women/91.jpg
# https://randomuser.me/api/portraits/women/69.jpg
# https://randomuser.me/api/portraits/women/50.jpg
# https://randomuser.me/api/portraits/women/22.jpg
# https://randomuser.me/api/portraits/women/76.jpg
# https://randomuser.me/api/portraits/women/49.jpg
# https://randomuser.me/api/portraits/women/86.jpg
# https://randomuser.me/api/portraits/women/71.jpg

# %%
# Generate a table with user info using a function with desired parameters (e.g., name, gender, city).
# Parameters depend on test requirements. Use Get Methods from the start of this notebook.
# Return a pandas dataframe with the users.
#Documntation found here: https://randomuser.me/documentation

def get_users():
    users =[]
     
    for user in RandomUser.generate_users(10):
        users.append({"Name":user.get_full_name(),"Gender":user.get_gender(),"City":user.get_city(),"State":user.get_state(),"Email":user.get_email(), "DOB":user.get_dob(),"Picture":user.get_picture()})
      
    return pd.DataFrame(users)

# %%
get_users()
# Out:
#                   Name  Gender              City                 State
# 0        Jackson White    male             Taupo            Wellington  \
# 1  Martinius Dyngeland    male           Skatval              Nordland
# 2     Ali Elmastaşoğlu    male         Gümüşhane                  Bolu
# 3       Mary Magnusson  female            Talvik  Finnmark - Finnmárku
# 4     Clarissa Schöner  female  Simmern/Hunsrück                Bremen
# 5       Peppi Kauppila  female          Kimitoön      Northern Savonia
# 6           Omar Ustad    male            Forset       Møre og Romsdal
# 7           Gülay Bähr  female      Haldensleben           Brandenburg
# 8        Ömür Yetkiner  female         Kırıkkale                Bingöl
# 9        Barbara Riley  female        Manchester         Hertfordshire
#
#                              Email                       DOB
# 0        jackson.white@example.com  1996-01-18T09:15:38.880Z  \
# 1  martinius.dyngeland@example.com  1974-12-14T12:00:39.367Z
# ...

# %%
#If we run the function again it will create another 10 different users. 
get_users()
# Out:
#               Name  Gender              City             State
# 0  Adolfine Arslan  female  Hitzacker (Elbe)            Bayern  \
# 1    Helmi Kilpela  female          Kyyjärvi       Kymenlaakso
# 2    Ronja Holmsen  female              Vang       Description
# 3    Xavier Lavoie    male          Radisson  British Columbia
# 4    Leevi Sippola    male          Uurainen      Ostrobothnia
# 5       Peetu Kari    male           Siuntio     North Karelia
# 6     Lohan Dufour    male             Lille             Loire
# 7     Ayse Petzold  female   Weiden I.D.Opf.            Bayern
# 8      Inaya Lucas  female      Villeurbanne               Lot
# 9  Amanda Karvonen  female        Kankaanpää   Tavastia Proper
#
#                          Email                       DOB
# 0  adolfine.arslan@example.com  1968-03-16T09:38:37.844Z  \
# 1    helmi.kilpela@example.com  1966-07-05T22:31:18.986Z
# 2    ronja.holmsen@example.com  1971-05-28T23:01:54.673Z
# ...

# %%
#We can also have a dataframe which we can use for further test cases.
df1 = pd.DataFrame(get_users())

# %% [markdown]
# Fruityvice API
# We will obtain the fruityvice API data using requests.get("url") function. The data is in a json format.

# %%
import requests
import json

# %%
data = requests.get("https://fruityvice.com/api/fruit/all")

# %%
results = json.loads(data.text)

# %%
pd.DataFrame(results)
# Out:
#                   name   id           family             order         genus
# 0            Persimmon   52        Ebenaceae           Rosales     Diospyros  \
# 1           Strawberry    3         Rosaceae           Rosales      Fragaria
# 2               Banana    1         Musaceae      Zingiberales          Musa
# 3               Tomato    5       Solanaceae         Solanales       Solanum
# 4                 Pear    4         Rosaceae           Rosales         Pyrus
# 5               Durian   60        Malvaceae          Malvales         Durio
# 6           Blackberry   64         Rosaceae           Rosales         Rubus
# 7          Lingonberry   65        Ericaceae          Ericales     Vaccinium
# 8                 Kiwi   66    Actinidiaceae  Struthioniformes       Apteryx
# 9               Lychee   67      Sapindaceae        Sapindales        Litchi
# 10           Pineapple   10     Bromeliaceae            Poales        Ananas
# ...

# %%
df2 = pd.json_normalize(results)

# %%
df2
# Out:
#                   name   id           family             order         genus
# 0            Persimmon   52        Ebenaceae           Rosales     Diospyros  \
# 1           Strawberry    3         Rosaceae           Rosales      Fragaria
# 2               Banana    1         Musaceae      Zingiberales          Musa
# 3               Tomato    5       Solanaceae         Solanales       Solanum
# 4                 Pear    4         Rosaceae           Rosales         Pyrus
# 5               Durian   60        Malvaceae          Malvales         Durio
# 6           Blackberry   64         Rosaceae           Rosales         Rubus
# 7          Lingonberry   65        Ericaceae          Ericales     Vaccinium
# 8                 Kiwi   66    Actinidiaceae  Struthioniformes       Apteryx
# 9               Lychee   67      Sapindaceae        Sapindales        Litchi
# 10           Pineapple   10     Bromeliaceae            Poales        Ananas
# ...

# %%
cherry = df2.loc[df2["name"] == 'Cherry']
(cherry.iloc[0]['family']) , (cherry.iloc[0]['genus'])
# Out:
# ('Rosaceae', 'Prunus')

# %%
#find out how many calories are contained in a banana.
cal_banana = df2.loc[df2["name"] == 'Banana']
cal_banana.iloc[0]['nutritions.calories']
# Out:
# 96

# %% [markdown]
# Official Joke API
# This API returns random jokes from a database.
#
# https://official-joke-api.appspot.com/jokes/ten

# %%
response = requests.get("https://official-joke-api.appspot.com/jokes/ten")
response.raise_for_status()

# %%
results2 = json.loads(data2.text)

# %%
df3 = pd.DataFrame(results2)
df3.drop(columns=["type","id"],inplace=True)
df3
# Out:
#                                             setup
# 0  Why did the octopus beat the shark in a fight?  \
# 1            What did the ocean say to the beach?
# 2  What did the duck say when he bought lipstick?
# 3         Want to hear a joke about construction?
# 4         Did you watch the new comic book movie?
# 5      Why couldn't the kid see the pirate movie?
# 6         Where does Fonzie like to go for lunch?
# 7     Where do rabbits go after they get married?
# 8            What did the ocean say to the shore?
# 9                 How does the moon cut his hair?
#
#                        punchline
# 0     Because it was well armed.
# 1   Thanks for all the sediment.
# 2              Put it on my bill
# 3  Nah, I'm still working on it.
# 4           It was very graphic!
# 5     Because it was rated arrr!
# 6           Chick-Fil-Eyyyyyyyy.
# 7               On a bunny-moon.
# 8        Nothing, it just waved.
# 9                    Eclipse it.
