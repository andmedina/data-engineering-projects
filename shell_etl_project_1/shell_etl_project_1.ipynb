# %% [markdown]
# #### Here I will showcase how we can use shell scripting for ETL operations.
# #### Goal
# - Showcase the power of shell scripting tranformations for simple tasks
# - Extract data from a delimited file.
# - Transform text data.
# - Load data into a database using shell commands.

# %% [markdown]
# #### 1. We can use the cut command to extract a substring and the parameter -c to specify the range of the substring
# ##### We can also use a comma to specify single characters

# %%
# !echo "database" | cut -c1-4
# Out:
# data

# %%
# !echo "database" | cut -c5-8
# Out:
# base

# %%
# !echo "database" | cut -c1,5
# Out:
# db

# %% [markdown]
# #### 2. Extracting fields/columns
#
# #### We can extract a specific column/field from a delimited text file, by mentioning
#
# - the delimiter using the -d option, or
# - the field number using the -f option.
#
# #### The /etc/passwd is a “:” delimited file.
#
# #### The command below extracts usernames (the first field) from /etc/passwd.

# %% [markdown]
# #### First let's look at the file before extracting the substring:

# %%
# !head -n 20 /etc/passwd
# Out:
# ##
# # User Database
# #
# # Note that this file is consulted directly only when the system is running
# # in single-user mode.  At other times this information is provided by
# # Open Directory.
# #
# # See the opendirectoryd(8) man page for additional information about
# # Open Directory.
# ##
# nobody:*:-2:-2:Unprivileged User:/var/empty:/usr/bin/false
# root:*:0:0:System Administrator:/var/root:/bin/sh
# daemon:*:1:1:System Services:/var/root:/usr/bin/false
# _uucp:*:4:4:Unix to Unix Copy Protocol:/var/spool/uucp:/usr/sbin/uucico
# _taskgated:*:13:13:Task Gate Daemon:/var/empty:/usr/bin/false
# _networkd:*:24:24:Network Services:/var/networkd:/usr/bin/false
# _installassistant:*:25:25:Install Assistant:/var/empty:/usr/bin/false
# _lp:*:26:26:Printing Services:/var/spool/cups:/usr/bin/false
# _postfix:*:27:27:Postfix Mail Server:/var/spool/postfix:/usr/bin/false
# _scsd:*:31:31:Service Configuration Service:/var/empty:/usr/bin/false

# %% [markdown]
# #### Now let's extract the substring of interest, which is the first field.
# - Each field is seperated by the delimeter ":"

# %%
# !cut -d":" -f1 /etc/passwd
# Out:
# ##
# # User Database
# #
# # Note that this file is consulted directly only when the system is running
# # in single-user mode.  At other times this information is provided by
# # Open Directory.
# #
# # See the opendirectoryd(8) man page for additional information about
# # Open Directory.
# ##
# nobody
# root
# daemon
# _uucp
# _taskgated
# _networkd
# _installassistant
# _lp
# _postfix
# _scsd
# _ces
# _appstore
# _mcxalr
# _appleevents
# _geod
# _devdocs
# _sandbox
# _mdnsresponder
# _ard
# _www
# _eppc
# _cvs
# _svn
# _mysql
# _sshd
# _qtss
# _cyrus
# _mailman
# _appserver
# _clamav
# _amavisd
# _jabber
# _appowner
# _windowserver
# _spotlight
# _tokend
# _securityagent
# _calendar
# _teamsserver
# _update_sharing
# _installer
# _atsserver
# _ftp
# _unknown
# _softwareupdate
# _coreaudiod
# _screensaver
# _locationd
# _trustevaluationagent
# _timezone
# _lda
# _cvmsroot
# _usbmuxd
# _dovecot
# _dpaudio
# _postgres
# _krbtgt
# _kadmin_admin
# _kadmin_changepw
# _devicemgr
# _webauthserver
# _netbios
# _warmd
# _dovenull
# _netstatistics
# _avbdeviced
# _krb_krbtgt
# _krb_kadmin
# _krb_changepw
# _krb_kerberos
# _krb_anonymous
# _assetcache
# _coremediaiod
# _launchservicesd
# _iconservices
# _distnote
# _nsurlsessiond
# _displaypolicyd
# _astris
# _krbfast
# _gamecontrollerd
# _mbsetupuser
# _ondemand
# _xserverdocs
# _wwwproxy
# _mobileasset
# _findmydevice
# _datadetectors
# _captiveagent
# _ctkd
# _applepay
# _hidd
# _cmiodalassistants
# _analyticsd
# _fpsd
# _timed
# _nearbyd
# _reportmemoryexception
# _driverkit
# _diskimagesiod
# _logd
# _appinstalld
# _installcoordinationd
# _demod
# _rmd
# _accessoryupdater
# _knowledgegraphd
# _coreml
# _sntpd
# _trustd
# _mmaintenanced
# _darwindaemon
# _notification_proxy
# _avphidbridge
# _biome
# _backgroundassets
# _mobilegestalthelper
# _audiomxd
# _terminusd
# _neuralengine
# _oahd

# %%
#Here we extract the first, third, and sixth fields.
# !cut -d":" -f1,3,6 /etc/passwd
# Out:
# ##
# # User Database
# #
# # Note that this file is consulted directly only when the system is running
# # in single-user mode.  At other times this information is provided by
# # Open Directory.
# #
# # See the opendirectoryd(8) man page for additional information about
# # Open Directory.
# ##
# nobody:-2:/var/empty
# root:0:/var/root
# daemon:1:/var/root
# _uucp:4:/var/spool/uucp
# _taskgated:13:/var/empty
# _networkd:24:/var/networkd
# _installassistant:25:/var/empty
# _lp:26:/var/spool/cups
# _postfix:27:/var/spool/postfix
# _scsd:31:/var/empty
# _ces:32:/var/empty
# _appstore:33:/var/db/appstore
# _mcxalr:54:/var/empty
# _appleevents:55:/var/empty
# _geod:56:/var/db/geod
# _devdocs:59:/var/empty
# _sandbox:60:/var/empty
# _mdnsresponder:65:/var/empty
# _ard:67:/var/empty
# _www:70:/Library/WebServer
# _eppc:71:/var/empty
# _cvs:72:/var/empty
# _svn:73:/var/empty
# _mysql:74:/var/empty
# _sshd:75:/var/empty
# _qtss:76:/var/empty
# _cyrus:77:/var/imap
# _mailman:78:/var/empty
# _appserver:79:/var/empty
# _clamav:82:/var/virusmails
# _amavisd:83:/var/virusmails
# _jabber:84:/var/empty
# _appowner:87:/var/empty
# _windowserver:88:/var/empty
# _spotlight:89:/var/empty
# _tokend:91:/var/empty
# _securityagent:92:/var/db/securityagent
# _calendar:93:/var/empty
# _teamsserver:94:/var/teamsserver
# _update_sharing:95:/var/empty
# _installer:96:/var/empty
# _atsserver:97:/var/empty
# _ftp:98:/var/empty
# _unknown:99:/var/empty
# _softwareupdate:200:/var/db/softwareupdate
# _coreaudiod:202:/var/empty
# _screensaver:203:/var/empty
# _locationd:205:/var/db/locationd
# _trustevaluationagent:208:/var/empty
# _timezone:210:/var/empty
# _lda:211:/var/empty
# _cvmsroot:212:/var/empty
# _usbmuxd:213:/var/db/lockdown
# _dovecot:214:/var/empty
# _dpaudio:215:/var/empty
# _postgres:216:/var/empty
# _krbtgt:217:/var/empty
# _kadmin_admin:218:/var/empty
# _kadmin_changepw:219:/var/empty
# _devicemgr:220:/var/empty
# _webauthserver:221:/var/empty
# _netbios:222:/var/empty
# _warmd:224:/var/empty
# _dovenull:227:/var/empty
# _netstatistics:228:/var/empty
# _avbdeviced:229:/var/empty
# _krb_krbtgt:230:/var/empty
# _krb_kadmin:231:/var/empty
# _krb_changepw:232:/var/empty
# _krb_kerberos:233:/var/empty
# _krb_anonymous:234:/var/empty
# _assetcache:235:/var/empty
# _coremediaiod:236:/var/empty
# _launchservicesd:239:/var/empty
# _iconservices:240:/var/empty
# _distnote:241:/var/empty
# _nsurlsessiond:242:/var/db/nsurlsessiond
# _displaypolicyd:244:/var/empty
# _astris:245:/var/db/astris
# _krbfast:246:/var/empty
# _gamecontrollerd:247:/var/empty
# _mbsetupuser:248:/var/setup
# _ondemand:249:/var/db/ondemand
# _xserverdocs:251:/var/empty
# _wwwproxy:252:/var/empty
# _mobileasset:253:/var/ma
# _findmydevice:254:/var/db/findmydevice
# _datadetectors:257:/var/db/datadetectors
# _captiveagent:258:/var/empty
# _ctkd:259:/var/empty
# _applepay:260:/var/db/applepay
# _hidd:261:/var/db/hidd
# _cmiodalassistants:262:/var/db/cmiodalassistants
# _analyticsd:263:/var/db/analyticsd
# _fpsd:265:/var/db/fpsd
# _timed:266:/var/db/timed
# _nearbyd:268:/var/db/nearbyd
# _reportmemoryexception:269:/var/db/reportmemoryexception
# _driverkit:270:/var/empty
# _diskimagesiod:271:/var/db/diskimagesiod
# _logd:272:/var/db/diagnostics
# _appinstalld:273:/var/db/appinstalld
# _installcoordinationd:274:/var/db/installcoordinationd
# _demod:275:/var/empty
# _rmd:277:/var/db/rmd
# _accessoryupdater:278:/var/db/accessoryupdater
# _knowledgegraphd:279:/var/db/knowledgegraphd
# _coreml:280:/var/db/coreml
# _sntpd:281:/var/empty
# _trustd:282:/var/empty
# _mmaintenanced:283:/var/db/mmaintenanced
# _darwindaemon:284:/var/db/darwindaemon
# _notification_proxy:285:/var/empty
# _avphidbridge:288:/var/empty
# _biome:289:/var/db/biome
# _backgroundassets:291:/var/empty
# _mobilegestalthelper:293:/var/empty
# _audiomxd:294:/var/db/audiomxd
# _terminusd:295:/var/empty
# _neuralengine:296:/var/db/neuralengine
# _oahd:441:/var/empty

# %%
#This is a range from the third field to the sixth field; end is inclusive.
# !cut -d":" -f3-6 /etc/passwd
# Out:
# ##
# # User Database
# #
# # Note that this file is consulted directly only when the system is running
# # in single-user mode.  At other times this information is provided by
# # Open Directory.
# #
# # See the opendirectoryd(8) man page for additional information about
# # Open Directory.
# ##
# -2:-2:Unprivileged User:/var/empty
# 0:0:System Administrator:/var/root
# 1:1:System Services:/var/root
# 4:4:Unix to Unix Copy Protocol:/var/spool/uucp
# 13:13:Task Gate Daemon:/var/empty
# 24:24:Network Services:/var/networkd
# 25:25:Install Assistant:/var/empty
# 26:26:Printing Services:/var/spool/cups
# 27:27:Postfix Mail Server:/var/spool/postfix
# 31:31:Service Configuration Service:/var/empty
# 32:32:Certificate Enrollment Service:/var/empty
# 33:33:Mac App Store Service:/var/db/appstore
# 54:54:MCX AppLaunch:/var/empty
# 55:55:AppleEvents Daemon:/var/empty
# 56:56:Geo Services Daemon:/var/db/geod
# 59:59:Developer Documentation:/var/empty
# 60:60:Seatbelt:/var/empty
# 65:65:mDNSResponder:/var/empty
# 67:67:Apple Remote Desktop:/var/empty
# 70:70:World Wide Web Server:/Library/WebServer
# 71:71:Apple Events User:/var/empty
# 72:72:CVS Server:/var/empty
# 73:73:SVN Server:/var/empty
# 74:74:MySQL Server:/var/empty
# 75:75:sshd Privilege separation:/var/empty
# 76:76:QuickTime Streaming Server:/var/empty
# 77:6:Cyrus Administrator:/var/imap
# 78:78:Mailman List Server:/var/empty
# 79:79:Application Server:/var/empty
# 82:82:ClamAV Daemon:/var/virusmails
# 83:83:AMaViS Daemon:/var/virusmails
# 84:84:Jabber XMPP Server:/var/empty
# 87:87:Application Owner:/var/empty
# 88:88:WindowServer:/var/empty
# 89:89:Spotlight:/var/empty
# 91:91:Token Daemon:/var/empty
# 92:92:SecurityAgent:/var/db/securityagent
# 93:93:Calendar:/var/empty
# 94:94:TeamsServer:/var/teamsserver
# 95:-2:Update Sharing:/var/empty
# 96:-2:Installer:/var/empty
# 97:97:ATS Server:/var/empty
# 98:-2:FTP Daemon:/var/empty
# 99:99:Unknown User:/var/empty
# 200:200:Software Update Service:/var/db/softwareupdate
# 202:202:Core Audio Daemon:/var/empty
# 203:203:Screensaver:/var/empty
# 205:205:Location Daemon:/var/db/locationd
# 208:208:Trust Evaluation Agent:/var/empty
# 210:210:AutoTimeZoneDaemon:/var/empty
# 211:211:Local Delivery Agent:/var/empty
# 212:212:CVMS Root:/var/empty
# 213:213:iPhone OS Device Helper:/var/db/lockdown
# 214:6:Dovecot Administrator:/var/empty
# 215:215:DP Audio:/var/empty
# 216:216:PostgreSQL Server:/var/empty
# 217:-2:Kerberos Ticket Granting Ticket:/var/empty
# 218:-2:Kerberos Admin Service:/var/empty
# 219:-2:Kerberos Change Password Service:/var/empty
# 220:220:Device Management Server:/var/empty
# 221:221:Web Auth Server:/var/empty
# 222:222:NetBIOS:/var/empty
# 224:224:Warm Daemon:/var/empty
# 227:227:Dovecot Authentication:/var/empty
# 228:228:Network Statistics Daemon:/var/empty
# 229:-2:Ethernet AVB Device Daemon:/var/empty
# 230:-2:Open Directory Kerberos Ticket Granting Ticket:/var/empty
# 231:-2:Open Directory Kerberos Admin Service:/var/empty
# 232:-2:Open Directory Kerberos Change Password Service:/var/empty
# 233:-2:Open Directory Kerberos:/var/empty
# 234:-2:Open Directory Kerberos Anonymous:/var/empty
# 235:235:Asset Cache Service:/var/empty
# 236:236:Core Media IO Daemon:/var/empty
# 239:239:_launchservicesd:/var/empty
# 240:240:IconServices:/var/empty
# 241:241:DistNote:/var/empty
# 242:242:NSURLSession Daemon:/var/db/nsurlsessiond
# 244:244:Display Policy Daemon:/var/empty
# 245:245:Astris Services:/var/db/astris
# 246:-2:Kerberos FAST Account:/var/empty
# 247:247:Game Controller Daemon:/var/empty
# 248:248:Setup User:/var/setup
# 249:249:On Demand Resource Daemon:/var/db/ondemand
# 251:251:macOS Server Documents Service:/var/empty
# 252:252:WWW Proxy:/var/empty
# 253:253:MobileAsset User:/var/ma
# 254:254:Find My Device Daemon:/var/db/findmydevice
# 257:257:DataDetectors:/var/db/datadetectors
# 258:258:captiveagent:/var/empty
# 259:259:ctkd Account:/var/empty
# 260:260:applepay Account:/var/db/applepay
# 261:261:HID Service User:/var/db/hidd
# 262:262:CoreMedia IO Assistants User:/var/db/cmiodalassistants
# 263:263:Analytics Daemon:/var/db/analyticsd
# 265:265:FPS Daemon:/var/db/fpsd
# 266:266:Time Sync Daemon:/var/db/timed
# 268:268:Proximity and Ranging Daemon:/var/db/nearbyd
# 269:269:ReportMemoryException:/var/db/reportmemoryexception
# 270:270:DriverKit:/var/empty
# 271:271:DiskImages IO Daemon:/var/db/diskimagesiod
# 272:272:Log Daemon:/var/db/diagnostics
# 273:273:App Install Daemon:/var/db/appinstalld
# 274:274:Install Coordination Daemon:/var/db/installcoordinationd
# 275:275:Demo Daemon:/var/empty
# 277:277:Remote Management Daemon:/var/db/rmd
# 278:278:Accessory Update Daemon:/var/db/accessoryupdater
# 279:279:Knowledge Graph Daemon:/var/db/knowledgegraphd
# 280:280:CoreML Services:/var/db/coreml
# 281:281:SNTP Server Daemon:/var/empty
# 282:282:trustd:/var/empty
# 283:283:mmaintenanced:/var/db/mmaintenanced
# 284:284:Darwin Daemon:/var/db/darwindaemon
# 285:285:Notification Proxy:/var/empty
# 288:288:Apple Virtual Platform HID Bridge:/var/empty
# 289:289:Biome:/var/db/biome
# 291:291:Background Assets Service:/var/empty
# 293:293:MobileGestaltHelper:/var/empty
# 294:294:Audio and MediaExperience Daemon:/var/db/audiomxd
# 295:295:Terminus:/var/empty
# 296:296:AppleNeuralEngine:/var/db/neuralengine
# 441:441:OAH Daemon:/var/empty

# %% [markdown]
# #### 3. Let's tranform data using the 'tr' command.
# - It is a filter command used to translate, squeeze, and/or delete characters.

# %%
#Convert all lower case to upper case 
# !echo "Shell Scripting" | tr "[a-z]" "[A-Z]"
# Out:
# SHELL SCRIPTING

# %%
#We can use a predefined 
# !echo "Shell Scripting" | tr "[:lower:]" "[:upper:]"
# Out:
# SHELL SCRIPTING

# %%
#Convert all upper to lowercase
# !echo "Shell Scripting" | tr  "[A-Z]" "[a-z]"
# Out:
# shell scripting

# %% [markdown]
# #### The squeeze command (tr -s) reduces consecutive occurrences of a specified character to a single occurrence.

# %%
# !echo "This    is    an    example     with    multiple    spaces" | tr -s " "
# Out:
# This is an example with multiple spaces

# %% [markdown]
# #### Can also delete using the -d paramter

# %%
# !echo "My login pin is 5634" | tr -d "[:digit:]"
# Out:
# My login pin is

# %% [markdown]
# ## Extract Data FROM a delimited file

# %% [markdown]
# #### 1. Create a table in database of choice.

# %%
import sqlite3

# Connect to SQLite database
conn = sqlite3.connect('database.db')

# Create a cursor object
cursor = conn.cursor()

# Drop the table if it exists
cursor.execute("DROP TABLE IF EXISTS template1;")

# Define the SQL query to create the table
create_table_query = """
CREATE TABLE template1 (
    username VARCHAR(50),
    userid INT,
    homedirectory VARCHAR(100)
);
"""

# Execute the query
cursor.execute(create_table_query)

# Commit the changes
conn.commit()

# Close the connection
conn.close()

# %% [markdown]
# ## Extraction

# %%
# !cut -d":" -f1,3,6 /etc/passwd > extracted-data.txt

# %%
# !cat extracted-data.txt
# Out:
# ##
# # User Database
# #
# # Note that this file is consulted directly only when the system is running
# # in single-user mode.  At other times this information is provided by
# # Open Directory.
# #
# # See the opendirectoryd(8) man page for additional information about
# # Open Directory.
# ##
# nobody:-2:/var/empty
# root:0:/var/root
# daemon:1:/var/root
# _uucp:4:/var/spool/uucp
# _taskgated:13:/var/empty
# _networkd:24:/var/networkd
# _installassistant:25:/var/empty
# _lp:26:/var/spool/cups
# _postfix:27:/var/spool/postfix
# _scsd:31:/var/empty
# _ces:32:/var/empty
# _appstore:33:/var/db/appstore
# _mcxalr:54:/var/empty
# _appleevents:55:/var/empty
# _geod:56:/var/db/geod
# _devdocs:59:/var/empty
# _sandbox:60:/var/empty
# _mdnsresponder:65:/var/empty
# _ard:67:/var/empty
# _www:70:/Library/WebServer
# _eppc:71:/var/empty
# _cvs:72:/var/empty
# _svn:73:/var/empty
# _mysql:74:/var/empty
# _sshd:75:/var/empty
# _qtss:76:/var/empty
# _cyrus:77:/var/imap
# _mailman:78:/var/empty
# _appserver:79:/var/empty
# _clamav:82:/var/virusmails
# _amavisd:83:/var/virusmails
# _jabber:84:/var/empty
# _appowner:87:/var/empty
# _windowserver:88:/var/empty
# _spotlight:89:/var/empty
# _tokend:91:/var/empty
# _securityagent:92:/var/db/securityagent
# _calendar:93:/var/empty
# _teamsserver:94:/var/teamsserver
# _update_sharing:95:/var/empty
# _installer:96:/var/empty
# _atsserver:97:/var/empty
# _ftp:98:/var/empty
# _unknown:99:/var/empty
# _softwareupdate:200:/var/db/softwareupdate
# _coreaudiod:202:/var/empty
# _screensaver:203:/var/empty
# _locationd:205:/var/db/locationd
# _trustevaluationagent:208:/var/empty
# _timezone:210:/var/empty
# _lda:211:/var/empty
# _cvmsroot:212:/var/empty
# _usbmuxd:213:/var/db/lockdown
# _dovecot:214:/var/empty
# _dpaudio:215:/var/empty
# _postgres:216:/var/empty
# _krbtgt:217:/var/empty
# _kadmin_admin:218:/var/empty
# _kadmin_changepw:219:/var/empty
# _devicemgr:220:/var/empty
# _webauthserver:221:/var/empty
# _netbios:222:/var/empty
# _warmd:224:/var/empty
# _dovenull:227:/var/empty
# _netstatistics:228:/var/empty
# _avbdeviced:229:/var/empty
# _krb_krbtgt:230:/var/empty
# _krb_kadmin:231:/var/empty
# _krb_changepw:232:/var/empty
# _krb_kerberos:233:/var/empty
# _krb_anonymous:234:/var/empty
# _assetcache:235:/var/empty
# _coremediaiod:236:/var/empty
# _launchservicesd:239:/var/empty
# _iconservices:240:/var/empty
# _distnote:241:/var/empty
# _nsurlsessiond:242:/var/db/nsurlsessiond
# _displaypolicyd:244:/var/empty
# _astris:245:/var/db/astris
# _krbfast:246:/var/empty
# _gamecontrollerd:247:/var/empty
# _mbsetupuser:248:/var/setup
# _ondemand:249:/var/db/ondemand
# _xserverdocs:251:/var/empty
# _wwwproxy:252:/var/empty
# _mobileasset:253:/var/ma
# _findmydevice:254:/var/db/findmydevice
# _datadetectors:257:/var/db/datadetectors
# _captiveagent:258:/var/empty
# _ctkd:259:/var/empty
# _applepay:260:/var/db/applepay
# _hidd:261:/var/db/hidd
# _cmiodalassistants:262:/var/db/cmiodalassistants
# _analyticsd:263:/var/db/analyticsd
# _fpsd:265:/var/db/fpsd
# _timed:266:/var/db/timed
# _nearbyd:268:/var/db/nearbyd
# _reportmemoryexception:269:/var/db/reportmemoryexception
# _driverkit:270:/var/empty
# _diskimagesiod:271:/var/db/diskimagesiod
# _logd:272:/var/db/diagnostics
# _appinstalld:273:/var/db/appinstalld
# _installcoordinationd:274:/var/db/installcoordinationd
# _demod:275:/var/empty
# _rmd:277:/var/db/rmd
# _accessoryupdater:278:/var/db/accessoryupdater
# _knowledgegraphd:279:/var/db/knowledgegraphd
# _coreml:280:/var/db/coreml
# _sntpd:281:/var/empty
# _trustd:282:/var/empty
# _mmaintenanced:283:/var/db/mmaintenanced
# _darwindaemon:284:/var/db/darwindaemon
# _notification_proxy:285:/var/empty
# _avphidbridge:288:/var/empty
# _biome:289:/var/db/biome
# _backgroundassets:291:/var/empty
# _mobilegestalthelper:293:/var/empty
# _audiomxd:294:/var/db/audiomxd
# _terminusd:295:/var/empty
# _neuralengine:296:/var/db/neuralengine
# _oahd:441:/var/empty

# %% [markdown]
# ## Transformation

# %%
# Step 1: Replace colons with commas
# !tr ":" "," < extracted-data.txt > transformed-data.csv

# Step 2: Remove the first 12 lines
# !sed '1,9d' transformed-data.csv > cleaned-data.csv

# %%
# !cat cleaned-data.csv
# Out:
# ##
# nobody,-2,/var/empty
# root,0,/var/root
# daemon,1,/var/root
# _uucp,4,/var/spool/uucp
# _taskgated,13,/var/empty
# _networkd,24,/var/networkd
# _installassistant,25,/var/empty
# _lp,26,/var/spool/cups
# _postfix,27,/var/spool/postfix
# _scsd,31,/var/empty
# _ces,32,/var/empty
# _appstore,33,/var/db/appstore
# _mcxalr,54,/var/empty
# _appleevents,55,/var/empty
# _geod,56,/var/db/geod
# _devdocs,59,/var/empty
# _sandbox,60,/var/empty
# _mdnsresponder,65,/var/empty
# _ard,67,/var/empty
# _www,70,/Library/WebServer
# _eppc,71,/var/empty
# _cvs,72,/var/empty
# _svn,73,/var/empty
# _mysql,74,/var/empty
# _sshd,75,/var/empty
# _qtss,76,/var/empty
# _cyrus,77,/var/imap
# _mailman,78,/var/empty
# _appserver,79,/var/empty
# _clamav,82,/var/virusmails
# _amavisd,83,/var/virusmails
# _jabber,84,/var/empty
# _appowner,87,/var/empty
# _windowserver,88,/var/empty
# _spotlight,89,/var/empty
# _tokend,91,/var/empty
# _securityagent,92,/var/db/securityagent
# _calendar,93,/var/empty
# _teamsserver,94,/var/teamsserver
# _update_sharing,95,/var/empty
# _installer,96,/var/empty
# _atsserver,97,/var/empty
# _ftp,98,/var/empty
# _unknown,99,/var/empty
# _softwareupdate,200,/var/db/softwareupdate
# _coreaudiod,202,/var/empty
# _screensaver,203,/var/empty
# _locationd,205,/var/db/locationd
# _trustevaluationagent,208,/var/empty
# _timezone,210,/var/empty
# _lda,211,/var/empty
# _cvmsroot,212,/var/empty
# _usbmuxd,213,/var/db/lockdown
# _dovecot,214,/var/empty
# _dpaudio,215,/var/empty
# _postgres,216,/var/empty
# _krbtgt,217,/var/empty
# _kadmin_admin,218,/var/empty
# _kadmin_changepw,219,/var/empty
# _devicemgr,220,/var/empty
# _webauthserver,221,/var/empty
# _netbios,222,/var/empty
# _warmd,224,/var/empty
# _dovenull,227,/var/empty
# _netstatistics,228,/var/empty
# _avbdeviced,229,/var/empty
# _krb_krbtgt,230,/var/empty
# _krb_kadmin,231,/var/empty
# _krb_changepw,232,/var/empty
# _krb_kerberos,233,/var/empty
# _krb_anonymous,234,/var/empty
# _assetcache,235,/var/empty
# _coremediaiod,236,/var/empty
# _launchservicesd,239,/var/empty
# _iconservices,240,/var/empty
# _distnote,241,/var/empty
# _nsurlsessiond,242,/var/db/nsurlsessiond
# _displaypolicyd,244,/var/empty
# _astris,245,/var/db/astris
# _krbfast,246,/var/empty
# _gamecontrollerd,247,/var/empty
# _mbsetupuser,248,/var/setup
# _ondemand,249,/var/db/ondemand
# _xserverdocs,251,/var/empty
# _wwwproxy,252,/var/empty
# _mobileasset,253,/var/ma
# _findmydevice,254,/var/db/findmydevice
# _datadetectors,257,/var/db/datadetectors
# _captiveagent,258,/var/empty
# _ctkd,259,/var/empty
# _applepay,260,/var/db/applepay
# _hidd,261,/var/db/hidd
# _cmiodalassistants,262,/var/db/cmiodalassistants
# _analyticsd,263,/var/db/analyticsd
# _fpsd,265,/var/db/fpsd
# _timed,266,/var/db/timed
# _nearbyd,268,/var/db/nearbyd
# _reportmemoryexception,269,/var/db/reportmemoryexception
# _driverkit,270,/var/empty
# _diskimagesiod,271,/var/db/diskimagesiod
# _logd,272,/var/db/diagnostics
# _appinstalld,273,/var/db/appinstalld
# _installcoordinationd,274,/var/db/installcoordinationd
# _demod,275,/var/empty
# _rmd,277,/var/db/rmd
# _accessoryupdater,278,/var/db/accessoryupdater
# _knowledgegraphd,279,/var/db/knowledgegraphd
# _coreml,280,/var/db/coreml
# _sntpd,281,/var/empty
# _trustd,282,/var/empty
# _mmaintenanced,283,/var/db/mmaintenanced
# _darwindaemon,284,/var/db/darwindaemon
# _notification_proxy,285,/var/empty
# _avphidbridge,288,/var/empty
# _biome,289,/var/db/biome
# _backgroundassets,291,/var/empty
# _mobilegestalthelper,293,/var/empty
# _audiomxd,294,/var/db/audiomxd
# _terminusd,295,/var/empty
# _neuralengine,296,/var/db/neuralengine
# _oahd,441,/var/empty

# %% [markdown]
# ## Load Phase

# %%
# !echo -e ".mode csv\n.import ./cleaned-data.csv template1" | sqlite3 database.db
# Out:
# ./cleaned-data.csv:1: expected 3 columns but found 1 - filling the rest with NULL

# %%
# !sqlite3 -column -header database.db "SELECT * FROM template1;"
# Out:
# username                userid  homedirectory
# ----------------------  ------  -----------------------------
# ##
# nobody                  -2      /var/empty
# root                    0       /var/root
# daemon                  1       /var/root
# _uucp                   4       /var/spool/uucp
# _taskgated              13      /var/empty
# _networkd               24      /var/networkd
# _installassistant       25      /var/empty
# _lp                     26      /var/spool/cups
# _postfix                27      /var/spool/postfix
# _scsd                   31      /var/empty
# _ces                    32      /var/empty
# _appstore               33      /var/db/appstore
# _mcxalr                 54      /var/empty
# _appleevents            55      /var/empty
# _geod                   56      /var/db/geod
# _devdocs                59      /var/empty
# _sandbox                60      /var/empty
# _mdnsresponder          65      /var/empty
# _ard                    67      /var/empty
# _www                    70      /Library/WebServer
# _eppc                   71      /var/empty
# _cvs                    72      /var/empty
# _svn                    73      /var/empty
# _mysql                  74      /var/empty
# _sshd                   75      /var/empty
# _qtss                   76      /var/empty
# _cyrus                  77      /var/imap
# _mailman                78      /var/empty
# _appserver              79      /var/empty
# _clamav                 82      /var/virusmails
# _amavisd                83      /var/virusmails
# _jabber                 84      /var/empty
# _appowner               87      /var/empty
# _windowserver           88      /var/empty
# _spotlight              89      /var/empty
# _tokend                 91      /var/empty
# _securityagent          92      /var/db/securityagent
# _calendar               93      /var/empty
# _teamsserver            94      /var/teamsserver
# _update_sharing         95      /var/empty
# _installer              96      /var/empty
# _atsserver              97      /var/empty
# _ftp                    98      /var/empty
# _unknown                99      /var/empty
# _softwareupdate         200     /var/db/softwareupdate
# _coreaudiod             202     /var/empty
# _screensaver            203     /var/empty
# _locationd              205     /var/db/locationd
# _trustevaluationagent   208     /var/empty
# _timezone               210     /var/empty
# _lda                    211     /var/empty
# _cvmsroot               212     /var/empty
# _usbmuxd                213     /var/db/lockdown
# _dovecot                214     /var/empty
# _dpaudio                215     /var/empty
# _postgres               216     /var/empty
# _krbtgt                 217     /var/empty
# _kadmin_admin           218     /var/empty
# _kadmin_changepw        219     /var/empty
# _devicemgr              220     /var/empty
# _webauthserver          221     /var/empty
# _netbios                222     /var/empty
# _warmd                  224     /var/empty
# _dovenull               227     /var/empty
# _netstatistics          228     /var/empty
# _avbdeviced             229     /var/empty
# _krb_krbtgt             230     /var/empty
# _krb_kadmin             231     /var/empty
# _krb_changepw           232     /var/empty
# _krb_kerberos           233     /var/empty
# _krb_anonymous          234     /var/empty
# _assetcache             235     /var/empty
# _coremediaiod           236     /var/empty
# _launchservicesd        239     /var/empty
# _iconservices           240     /var/empty
# _distnote               241     /var/empty
# _nsurlsessiond          242     /var/db/nsurlsessiond
# _displaypolicyd         244     /var/empty
# _astris                 245     /var/db/astris
# _krbfast                246     /var/empty
# _gamecontrollerd        247     /var/empty
# _mbsetupuser            248     /var/setup
# _ondemand               249     /var/db/ondemand
# _xserverdocs            251     /var/empty
# _wwwproxy               252     /var/empty
# _mobileasset            253     /var/ma
# _findmydevice           254     /var/db/findmydevice
# _datadetectors          257     /var/db/datadetectors
# _captiveagent           258     /var/empty
# _ctkd                   259     /var/empty
# _applepay               260     /var/db/applepay
# _hidd                   261     /var/db/hidd
# _cmiodalassistants      262     /var/db/cmiodalassistants
# _analyticsd             263     /var/db/analyticsd
# _fpsd                   265     /var/db/fpsd
# _timed                  266     /var/db/timed
# _nearbyd                268     /var/db/nearbyd
# _reportmemoryexception  269     /var/db/reportmemoryexception
# _driverkit              270     /var/empty
# _diskimagesiod          271     /var/db/diskimagesiod
# _logd                   272     /var/db/diagnostics
# _appinstalld            273     /var/db/appinstalld
# _installcoordinationd   274     /var/db/installcoordinationd
# _demod                  275     /var/empty
# _rmd                    277     /var/db/rmd
# _accessoryupdater       278     /var/db/accessoryupdater
# _knowledgegraphd        279     /var/db/knowledgegraphd
# _coreml                 280     /var/db/coreml
# _sntpd                  281     /var/empty
# _trustd                 282     /var/empty
# _mmaintenanced          283     /var/db/mmaintenanced
# _darwindaemon           284     /var/db/darwindaemon
# _notification_proxy     285     /var/empty
# _avphidbridge           288     /var/empty
# _biome                  289     /var/db/biome
# _backgroundassets       291     /var/empty
# _mobilegestalthelper    293     /var/empty
# _audiomxd               294     /var/db/audiomxd
# _terminusd              295     /var/empty
# _neuralengine           296     /var/db/neuralengine
# _oahd                   441     /var/empty

# %% [markdown]
# #### In a production environment the shell command would go in a scripting file instead. The purpose of using an ipynb format was to showcase the power of shell scripting for simple ETL tasks.
